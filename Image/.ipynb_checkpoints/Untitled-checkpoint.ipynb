# %% [markdown]
# # 🐍 Convert images into neural networks with skimage.feature 🖼️
#
# ❓ **Did you know an image can be transformed into a neural network?**
# Images are more than just pixels—they are structured, interconnected patterns. Today, let's explore how to convert an image into a **graph** using **skimage.feature** and visualize its structure like a neural network. 🚀
#
# ## 👉 **Solution: Graphs from Images**
# We use **Canny Edge Detection** to detect image edges and then construct a **graph**, where each node represents a key point in the image.
#
# 🔧 **How does it work?**
# - 📸 Convert an image to grayscale.
# - 🖼️ Apply **Canny Edge Detection** to extract contours.
# - 🔗 Build a **graph**, where each node is an edge pixel connected to its neighbors.
# - 🎨 Visualize the graph structure over the original image.
#
# 🔎 **Why does it matter?**
# Graphs are powerful tools in computer vision, used in:
# ✔ **Pattern recognition** 📐 - Detecting shapes and objects in images.
# ✔ **Image segmentation** 🎭 - Identifying regions in medical and satellite images.
# ✔ **Graph Neural Networks (GNNs)** 🧠 - Enabling structural learning for advanced vision tasks.
#
# ✨ **Real-world Example: Graphs in Medical Imaging**
# In **biomedical applications**, graphs help analyze **neuronal connections in MRI scans**. They also aid in detecting **cancer cells by modeling their structural patterns**.
#
# ⚙️ **Business Impact**
# ✅ Enhances **image segmentation and classification** in computer vision.
# ✅ Improves **anomaly detection** in medical and security imaging.
# ✅ Enables **advanced structural analysis** in documents, maps, and schematics.
#
# 📊 **Code Summary**
# 1️⃣ Load a sample image from `skimage.data`.
# 2️⃣ Apply **Canny Edge Detection** (`skimage.feature.canny`).
# 3️⃣ Construct a **graph** using `networkx`.
# 4️⃣ Visualize the graph structure over the image.
#
# 🔗[Github](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
#
# 💭 **How would you use this technique in your industry?**
#
# 🔑 #DataScience #ComputerVision #MachineLearning #GraphNeuralNetworks #Python #ArtificialIntelligence
#
# ---
#
# # 🐍 Convertir imágenes en redes neuronales con skimage.feature 🖼️
#
# ❓ **¿Sabías que una imagen puede transformarse en una red neuronal?**
# Las imágenes no son solo píxeles; son estructuras interconectadas llenas de patrones. Hoy exploramos cómo convertir una imagen en un **grafo** utilizando **skimage.feature** y visualizar su estructura como si fuera una red neuronal. 🚀
#
# ## 👉 **Solución: Grafos a partir de imágenes**
# Utilizamos **Canny Edge Detection** para detectar los bordes de una imagen y luego construimos un **grafo**, donde cada nodo representa un punto clave en la imagen.
#
# 🔧 **¿Cómo funciona?**
# - 📸 Tomamos una imagen y la convertimos a escala de grises.
# - 🖼️ Aplicamos **Canny Edge Detection** para identificar los contornos.
# - 🔗 Construimos un **grafo** donde cada nodo es un píxel de borde y sus conexiones representan relaciones espaciales.
# - 🎨 Visualizamos la estructura conectada del grafo sobre la imagen original.
#
# 🔎 **¿Por qué importa?**
# Los **grafos** son herramientas poderosas en visión computacional, con aplicaciones en:
# ✔ **Reconocimiento de patrones** 📐 - Detección de formas y objetos en imágenes.
# ✔ **Segmentación de imágenes** 🎭 - Identificación de regiones en imágenes médicas y satelitales.
# ✔ **Redes Neuronales en Grafos (GNNs)** 🧠 - Permiten entrenar modelos para análisis estructural avanzado.
#
# ✨ **Ejemplo Real: Grafos en imágenes médicas**
# En aplicaciones biomédicas, los **grafos permiten analizar conexiones neuronales en imágenes de resonancia magnética**. También se utilizan en la detección de células cancerígenas al modelar sus patrones estructurales.
#
# ⚙️ **Impacto en el negocio**
# ✅ Optimiza la **segmentación y clasificación de imágenes** en visión computacional.
# ✅ Mejora la **detección de anomalías** en imágenes médicas y de seguridad.
# ✅ Permite **análisis estructural avanzado** en documentos, planos y mapas.
#
# 📊 **Resumen del código**
# 1️⃣ Carga una imagen de ejemplo con `skimage.data`.
# 2️⃣ Aplica **Canny Edge Detection** (`skimage.feature.canny`).
# 3️⃣ Construye un **grafo** con `networkx`.
# 4️⃣ Visualiza la estructura del grafo superpuesta en la imagen.
#
# 🔗[Github](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
#
# 💭 **¿Cómo aplicarías esta técnica en tu industria?**
#
# 🔑 #DataScience #ComputerVision #MachineLearning #GraphNeuralNetworks #Python #ArtificialIntelligence

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from skimage import data, color, feature

# Load a sample image (coins dataset from skimage)
image = data.coins()

# Convert image to grayscale if not already
gray_image = color.rgb2gray(image) if len(image.shape) == 3 else image

# Extract edges using Canny edge detection from skimage.feature
edges = feature.canny(gray_image, sigma=2)

# Create an empty graph
graph = nx.Graph()

# Get the dimensions of the image
height, width = edges.shape

# Add nodes: Each pixel that is an edge becomes a node
for y in range(height):
    for x in range(width):
        if edges[y, x]:  # If it's an edge pixel
            graph.add_node((y, x))

# Add edges: Connect each node to its adjacent edge pixels
for y in range(height - 1):
    for x in range(width - 1):
        if edges[y, x]:
            # Connect horizontally and vertically
            if edges[y + 1, x]:
                graph.add_edge((y, x), (y + 1, x))
            if edges[y, x + 1]:
                graph.add_edge((y, x), (y, x + 1))

# Plot the results
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Original grayscale image
ax[0].imshow(gray_image, cmap="gray")
ax[0].set_title("Original Image")

# Graph representation overlaying edges
ax[1].imshow(gray_image, cmap="gray")
nx.draw(graph, pos={node: node[::-1] for node in graph.nodes()}, node_size=1, edge_color="red", ax=ax[1])
ax[1].set_title("Neural Network Graph Representation (Neural Network Structure)")

plt.show()
