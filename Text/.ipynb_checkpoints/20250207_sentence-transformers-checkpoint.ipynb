# %% [markdown]
# ## 🐍 Python: Convert Text to Embeddings in Pandas 📊
#
# ❓ **Ever wondered how to transform simple text into powerful vectors that boost data analysis?**
#
# ### 👉 Solution
# We use *sentence-transformers* to convert each text string into a numerical embedding and store it in a Pandas DataFrame.
#
# ### 🔧 How it works
# 🔹 The model converts each text into a vector capturing its semantic meaning.
# 🔹 It integrates seamlessly with tabular models for advanced analysis and visualization.
# 🔹 The approach is adaptable: for image processing, load the appropriate vision model and adjust the preprocessing accordingly.
#
# ### 🔎 Why it matters
# 🔹 It bridges NLP with structured data analysis.
# 🔹 Opens opportunities to extract deep insights from large datasets.
# 🔹 Empowers the creation of innovative solutions in data science and AI.
#
# ### ✨ Real-world Example or Use Case
# 🔹 A DataFrame is created with sample text entries.
# 🔹 Each text is transformed into an embedding using a pre-trained model.
# 🔹 Dimensionality reduction (using PCA) is applied to visualize embeddings in a 2D plot.
#
# ### ⚙️ Business Impact
# 🔹 Enhances the integration of NLP into decision-making processes.
# 🔹 Optimizes the interpretation of complex data, driving innovation and efficiency.
#
# ### 📊 Code Summary
# 🔹 The code generates embeddings from texts, integrates them into a DataFrame, and visualizes their relationships in a 2D plot.
#
# 🔗 [Github](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
#
# 💭 **Reflection:** How would you tackle this challenge in your daily projects? Share your insights!
#
# 🔑 #Python #DataScience #NLP #Pandas #MachineLearning
# Reference: Reimers, Nils, and Iryna Gurevych. "Sentence-BERT: Sentence Embeddings using Siamese BERT-Networks." *arXiv preprint arXiv:1908.10084* (2019).
#
# ----
#
# ## 🐍 Python: Convertir texto en embeddings dentro de Pandas 📊
#
# ❓ **¿Te has preguntado cómo transformar simples textos en poderosos vectores que impulsen el análisis de datos?**
#
# ### 👉 Solución
# Utilizamos *sentence-transformers* para convertir cada cadena de texto en un embedding numérico y almacenarlo en un DataFrame de Pandas.
#
# ### 🔧 ¿Cómo funciona?
# 🔹 El modelo convierte cada texto en un vector que captura su significado semántico.
# 🔹 Se integra fácilmente con modelos tabulares para análisis y visualización.
# 🔹 La técnica se puede adaptar: si se desea procesar imágenes, se debe cargar el modelo especializado en visión por computadora y ajustar el preprocesamiento.
#
# ### 🔎 ¿Por qué importa?
# 🔹 Permite fusionar NLP con datos estructurados.
# 🔹 Abre oportunidades para descubrir insights profundos en grandes volúmenes de información.
# 🔹 Facilita la creación de soluciones innovadoras en ciencia de datos e inteligencia artificial.
#
# ### ✨ Ejemplo real o Caso práctico
# 🔹 Se crea un DataFrame con textos de muestra.
# 🔹 Cada texto se transforma en un embedding utilizando un modelo preentrenado.
# 🔹 Se reduce la dimensionalidad (usando PCA) para visualizar los embeddings en un gráfico 2D.
#
# ### ⚙️ Impacto en el negocio
# 🔹 Potencia la integración de análisis de lenguaje natural en procesos de toma de decisiones.
# 🔹 Optimiza la interpretación de datos complejos, impulsando la innovación y la eficiencia.
#
# ### 📊 Resumen de qué se hace en el código
# 🔹 El código genera embeddings a partir de textos, los integra en un DataFrame y visualiza sus relaciones en un gráfico 2D.
#
# 🔗 [Github](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
#
# 💭 **Reflexión:** ¿Cómo abordarías este desafío en tus proyectos diarios? ¡Comparte tu experiencia!
#
# 🔑 #Python #DataScience #NLP #Pandas #MachineLearning
# Referencia: Reimers, Nils, y Iryna Gurevych. "Sentence-BERT: Sentence Embeddings using Siamese BERT-Networks." *arXiv preprint arXiv:1908.10084* (2019).

# %%
# Import necessary libraries
import pandas as pd                # For data manipulation and DataFrame creation
from sentence_transformers import SentenceTransformer  # For generating text embeddings
import matplotlib.pyplot as plt    # For plotting graphs
import numpy as np                 # For numerical operations
from sklearn.decomposition import PCA  # For reducing dimensionality for visualization

# Create a sample DataFrame with text data
data = {
    'id': [1, 2, 3, 4, 5],
    'text': [
        "Artificial Intelligence is transforming industries.",
        "Data Science makes complex data accessible.",
        "Machine learning algorithms power modern solutions.",
        "Deep learning enables breakthrough innovations.",
        "Natural Language Processing unlocks insights from text."
    ]
}
df = pd.DataFrame(data)  # Initialize the DataFrame with sample data

# Load a pre-trained SentenceTransformer model
# The model 'all-MiniLM-L6-v2' is chosen for its balance between speed and accuracy
model = SentenceTransformer('all-MiniLM-L6-v2')

# Compute embeddings for each text entry and store them in a new DataFrame column
df['embeddings'] = df['text'].apply(lambda x: model.encode(x))

# Stack the embeddings into a numpy array for dimensionality reduction
embedding_matrix = np.stack(df['embeddings'].values)

# Apply PCA to reduce the embeddings from their original dimension to 2D for visualization
pca = PCA(n_components=2)
embedding_2d = pca.fit_transform(embedding_matrix)

# Add the 2D coordinates to the DataFrame for plotting
df['x'] = embedding_2d[:, 0]  # First principal component
df['y'] = embedding_2d[:, 1]  # Second principal component

# Plot the 2D embeddings
plt.figure(figsize=(8, 6))  # Set the figure size for clarity
plt.scatter(df['x'], df['y'], color='blue')  # Create a scatter plot with the 2D coordinates

# Annotate each point with its corresponding id for identification
for index, row in df.iterrows():
    plt.annotate(f"{row['id']}", (row['x'], row['y']), textcoords="offset points", xytext=(0, 10), ha='center')

# Set the title and labels for the plot to improve readability
plt.title("2D Visualization of Text Embeddings")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.grid(True)  # Add a grid for easier interpretation of the plot
plt.show()  # Display the plot

# %%
df
# Out:
#    id                                               text  \
# 0   1  Artificial Intelligence is transforming indust...
# 1   2        Data Science makes complex data accessible.
# 2   3  Machine learning algorithms power modern solut...
# 3   4    Deep learning enables breakthrough innovations.
# 4   5  Natural Language Processing unlocks insights f...
#
#                                           embeddings         x         y
# 0  [0.036085233, -0.024478914, 0.05895452, -0.003...  0.242559  0.239969
# 1  [-0.03761002, 0.010631462, -0.03147874, 0.0303... -0.524940  0.412430
# 2  [-0.052016456, 0.031689744, 0.06891376, -0.021...  0.250448  0.266323
# 3  [-0.042945087, -0.06667887, 0.059103176, -0.00...  0.496850 -0.348874
# 4  [0.020065278, -0.008445144, 0.1004348, 0.01877... -0.464917 -0.569848

# %% [markdown]
# # 📊 Understanding the Graph: Visualizing Text Embeddings
#
# The graph is a **2D visualization of text embeddings**, helping us see how different pieces of text relate based on their meaning.
#
# ## 🔎 What does each element represent?
#
# - **Each point = One text**
#   Each text in our dataset has been converted into a **numerical vector (embedding)** that captures its meaning. Originally, these vectors had many dimensions, but we reduced them to **two dimensions using PCA** to make them plottable.
#
# - **Position in the graph = Semantic similarity**
#   - Texts with **similar meanings** are positioned **closer** together.
#   - Texts with **different meanings** are positioned **farther apart**.
#   - If two points are close, it suggests their text content shares common themes or context.
#
# - **X and Y axes = Compressed meaning**
#   - The **X-axis (PCA Component 1)** captures the most significant variation in the text data.
#   - The **Y-axis (PCA Component 2)** captures additional but less dominant variations.
#   - These axes **don’t have specific meanings** (like time or price in a standard graph), but together they help position texts based on relationships.
#
# - **Numbers on the graph = Text IDs**
#   Each point is labeled with an **ID number**, so we can identify which text it represents in the dataset.
#
# ## ⚙️ Why is this useful?
# By visualizing text embeddings, we can:
# ✔️ Understand how texts are grouped based on meaning.
# ✔️ Detect patterns or clusters of similar topics.
# ✔️ Improve text analysis in machine learning applications.
#
# In short, this graph **transforms words into numbers and then into a visual representation of meaning**—allowing us to "see" the relationships between different pieces of text. 🚀
