# %% [markdown]
# # 🐍 Python OCR Text Extraction 📸
#
# ## ❓ Ever wondered how you can digitize text from images without manually typing it out? 🙃
#
# 👉 Solution: Use **pytesseract** for OCR (Optical Character Recognition) to extract text from images and convert it into editable digital documents.
#
# ## 🔧 How does it work?
#
# - **Pytesseract** reads the image and recognizes any text.
# - It's perfect for converting scanned documents, handwritten notes, or any image with visible text.
# - After applying OCR, you'll have a clean, editable digital version of the text, ready to be processed or stored.
#
# ## 🔎 Why does it matter?
#
# In today’s digital world, the ability to convert physical documents or images into editable text with just a click makes our work more efficient, especially when dealing with **data extraction**, **archiving**, or even analyzing documents with **data science** techniques.
#
# ## ✨ Real Example or Practical Case:
#
# Let’s say you want to digitize a **scanned receipt** or **invoice** with structured or unstructured data. With OCR, you can automate this task and save valuable time. For example, extracting names and amounts from an image of a receipt can help businesses automate their bookkeeping processes.
#
# ## ⚙️ Business Impact:
#
# - **Automation**: Reduces manual labor in data entry.
# - **Time-saving**: Quickly extract and digitize data from various sources.
# - **Accuracy**: OCR can improve the consistency of data extraction across documents.
#
# ## 📊 Code Overview:
#
# - **Input**: Image containing text.
# - **Output**: Extracted text from the image.
# - **Libraries used**: `pytesseract`, `PIL`, `matplotlib`.
# - **Process**: Image is preprocessed (converted to grayscale, resized, and optimized), and text is extracted via pytesseract.
#
# ## 💭 Reflection:
#
# How would you approach automating text extraction in your projects? Do you see OCR as a solution to streamline your workflow?
#
# ## 🔗 [GitHub](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
#
# ## 🔑 #AI #DataScience #Python #OCR #MachineLearning #Automation #DataProcessing #TextExtraction #Tesseract #OCRTech #DeepLearning
#
# # 🐍 Python Extracción de texto con OCR 📸
#
# ## ❓ ¿Alguna vez te has preguntado cómo puedes digitalizar texto de imágenes sin tener que escribirlo manualmente? 🙃
#
# 👉 Solución: Usa **pytesseract** para OCR (Reconocimiento Óptico de Caracteres) para extraer texto de imágenes y convertirlo en documentos digitales editables.
#
# ## 🔧 ¿Cómo funciona?
#
# - **Pytesseract** lee la imagen y reconoce cualquier texto.
# - Es perfecto para convertir documentos escaneados, notas manuscritas o cualquier imagen con texto visible.
# - Después de aplicar OCR, tendrás una versión digital limpia y editable del texto, lista para ser procesada o almacenada.
#
# ## 🔎 ¿Por qué es importante?
#
# En el mundo digital de hoy, la capacidad de convertir documentos físicos o imágenes en texto editable con solo un clic hace nuestro trabajo mucho más eficiente, especialmente cuando se trata de **extracción de datos**, **archivo de documentos** o incluso de analizar documentos con técnicas de **ciencia de datos**.
#
# ## ✨ Ejemplo real o Caso práctico:
#
# Supongamos que quieres digitalizar un **recibo escaneado** o **factura** con datos estructurados o no estructurados. Con OCR, puedes automatizar esta tarea y ahorrar tiempo valioso. Por ejemplo, extraer nombres y cantidades de una imagen de un recibo puede ayudar a las empresas a automatizar sus procesos contables.
#
# ## ⚙️ Impacto en el negocio:
#
# - **Automatización**: Reduce el trabajo manual de entrada de datos.
# - **Ahorro de tiempo**: Extrae y digitaliza datos de diversas fuentes rápidamente.
# - **Precisión**: OCR puede mejorar la consistencia de la extracción de datos en documentos.
#
# ## 📊 Resumen del código:
#
# - **Entrada**: Imagen que contiene texto.
# - **Salida**: Texto extraído de la imagen.
# - **Librerías utilizadas**: `pytesseract`, `PIL`, `matplotlib`.
# - **Proceso**: La imagen es preprocesada (convertida a escala de grises, redimensionada y optimizada), y se extrae el texto mediante pytesseract.
#
# 💭 Reflexión:
#
# ¿Cómo abordarías la automatización de la extracción de texto en tus proyectos? ¿Ves OCR como una solución para agilizar tu flujo de trabajo?
#
# ## 🔗 [GitHub](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
#
# ## 🔑 #IA #CienciaDeDatos #Python #OCR #AprendizajeAutomático #Automatización #ProcesamientoDeDatos #ExtracciónDeTexto #Tesseract #TecnologíaOCR #AprendizajeProfundo

# %%
# Import necessary libraries
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt

# Function to extract text from an image
def extract_text_from_image(image_path):
    # Open the image using PIL (Python Imaging Library)
    image = Image.open(image_path)

    
    # Preprocess the image (convert to grayscale, enhance, etc.)
    image = image.convert('L')  # Convert to grayscale to simplify processing


    # Optional: Resize the image for better OCR accuracy (increase size)
    image = image.resize((image.width * 2, image.height * 2), Image.LANCZOS)  # Resize for better accuracy

    # Use pytesseract to extract text
    extracted_text = pytesseract.image_to_string(image)

    return extracted_text

# Load an example image from an online source (replace with your image path)
image_path = '20250422_ Python OCR Extraction.jpeg'

# Call the function and extract text
text = extract_text_from_image(image_path)

# Show the image and extracted text
image = Image.open(image_path)
plt.imshow(image)
plt.axis('off')  # Hide the axes for a cleaner view
plt.show()

# Print extracted text
print("Extracted Text from Image:")
print(text)

# Save extracted text into a text file
with open("extracted_text.txt", "w") as file:
    file.write(text)
# Out:
# Extracted Text from Image:
# BS
# BBVA
#
# eff Mi primera Tarjeta
#
# 4000 0012 3456 7899
#
# pesos 2019 = toe 12. 22
# EMILIO VILLAGRAN VISA
# © VALIDA SOLO EN MEXICO/VALID ONLY INMEXICO: Ly
