# %% [markdown]
# # 🐍 Python: Convert Text to Speech 🗣️
#
# ❓ **Have you ever wondered how to transform text into audio to make it more accessible?**
# 👉 **Today, we will use Pyttsx3, a Python library that converts text to speech in real-time.**
#
# ## 🔧 How does it work?
# Pyttsx3 allows us to generate speech from text and adjust features such as speed and pitch, making it useful for visually impaired users or simply to listen to notes instead of reading them.
#
# ## 🔎 Why does it matter?
# This technique improves accessibility and can be used to automatically read reports or results, a key factor in boosting productivity for data science or AI teams.
#
# ## ✨ Real-world example or case study:
# In this example, we’ll use text generated by a data analysis system to read it aloud. The most common application is in work environments or educational platforms, where speech is used to convey information efficiently without needing to look at a screen.
#
# ## ⚙️ Business Impact:
# Companies developing educational platforms or accessibility software can enhance user experience by allowing users to interact with data in a smoother and more comfortable way.
#
# ## 📊 Summary of what the code does:
# - **Pyttsx3 library**: converts text into speech.
# - **Custom settings**: adjusting voice speed and tone.
# - **Text input**: any text can be read effectively.
#
# 🔗 [Github](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
# 💭 **Reflection**:
# What applications do you see for this tool in your day-to-day work? 🤔 Let technology work for you!
#
# 🔑 #DataScience #Python #MachineLearning #AI #Innovation #Accessibility #TechForGood #VoiceTech #Productivity
#
# -----
#
# # 🐍 Python: Convertir texto a voz 🗣️
#
# ❓ **¿Alguna vez te has preguntado cómo transformar texto en audio para hacerlo más accesible?**
# 👉 **Hoy vamos a usar Pyttsx3, una librería de Python que convierte texto a voz en tiempo real.**
#
# ## 🔧 ¿Cómo funciona?
# Pyttsx3 nos permite generar voz a partir de texto y ajustar aspectos como la velocidad y la tonalidad de la voz, lo que lo hace muy útil para personas con discapacidades visuales o simplemente para hacer que las notas se lean en lugar de tener que leerlas.
#
# ## 🔎 ¿Por qué importa?
# Esta técnica no solo mejora la accesibilidad, sino que también puede ser utilizada para optimizar tareas como leer reportes o resultados automáticamente, un factor clave para la productividad en equipos de ciencia de datos o inteligencia artificial.
#
# ## ✨ Ejemplo real o Caso práctico:
# En este ejemplo, utilizaremos texto generado por un sistema de análisis de datos para leerlo en voz alta. La aplicación más común es en entornos de trabajo o incluso en aplicaciones educativas, donde la voz se usa para transmitir información de manera eficiente y sin necesidad de mirar una pantalla.
#
# ## ⚙️ Impacto en el negocio:
# Empresas que desarrollan plataformas de educación o software de accesibilidad pueden mejorar la experiencia del usuario, permitiendo a los usuarios interactuar con la información de una manera más fluida y cómoda.
#
# ## 📊 Resumen de qué se hace en el código:
# - **Librería Pyttsx3**: convierte texto a voz.
# - **Configuración personalizada**: ajustamos la velocidad y el tono de la voz.
# - **Texto como entrada**: cualquier texto puede ser leído de manera efectiva.
#
# 🔗 [Github](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
# 💭 **Reflexión**:
# ¿Qué aplicaciones ves para esta herramienta en tu entorno? 🤔 ¡Haz que la tecnología trabaje a tu favor!
#
# 🔑 #DataScience #Python #MachineLearning #AI #Innovation #Accessibility #TechForGood #VoiceTech #Productivity
#
# ![image.png](attachment:240b881f-369c-41ea-bb9d-1fbc368191b9.png)
#
# # Code in Jupyter Notebook:
#
# ```python
# # Importing the pyttsx3 library to convert text to speech
# import pyttsx3
#
# # Initialize the text-to-speech engine
# engine = pyttsx3.init()
#
# # Setting properties for voice speed (rate) and volume
# engine.setProperty('rate', 150)  # Speed of speech (higher is faster)
# engine.setProperty('volume', 1)  # Volume level (from 0.0 to 1.0)
#
# # Getting available voices
# voices = engine.getProperty('voices')
#
# # Setting voice (optional, choose a different voice index if available)
# engine.setProperty('voice', voices[1].id)  # 0 for male, 1 for female
#
# # Text to be converted into speech
# text = "Hello, welcome to the world of Python and Data Science. Let's explore how text to speech works!"
#
# # Make the engine say the text aloud
# engine.say(text)
#
# # Wait until the speech is finished
# engine.runAndWait()

# %%
# Importing the pyttsx3 library to convert text to speech
import pyttsx3 

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Setting properties for voice speed (rate) and volume
engine.setProperty('rate', 150)  # Speed of speech (higher is faster)
engine.setProperty('volume', 1)  # Volume level (from 0.0 to 1.0)

# Getting available voices
voices = engine.getProperty('voices')

# Setting voice (optional, choose a different voice index if available)
engine.setProperty('voice', voices[1].id)  # 0 for male, 1 for female

# Text to be converted into speech
text = "Hello, welcome to the world of Python and Data Science. Let's explore how text to speech works!"

# Make the engine say the text aloud
engine.say(text)

# Wait until the speech is finished
engine.runAndWait()
